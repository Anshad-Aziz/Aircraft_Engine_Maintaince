# %% [markdown]
# <a href="https://colab.research.google.com/github/Anshad-Aziz/Aircraft_Engine_Maintaince/blob/main/Aircraft_Engine_Maintance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import accuracy_score,classification_report

# %%
df_train=pd.read_excel('/content/PM_train.xlsx')
df_test=pd.read_excel('/content/PM_test.xlsx')
df_truth=pd.read_excel('/content/PM_truth.xlsx')

# %%
df=pd.concat([df_train,df_test],ignore_index=True)

# %%
df.head(3)
# Out:
#    id  cycle  setting1  setting2  setting3      s1      s2       s3       s4  \
# 0   1      1   -0.0007   -0.0004       100  518.67  641.82  1589.70  1400.60
# 1   1      2    0.0019   -0.0003       100  518.67  642.15  1591.82  1403.14
# 2   1      3   -0.0043    0.0003       100  518.67  642.35  1587.99  1404.20
#
#       s5  ...     s12      s13      s14     s15   s16    s17   s18  s19  \
# 0  14.62  ...  521.66  2388.02  8138.62  8.4195  0.03  392.0  2388  100
# 1  14.62  ...  522.28  2388.07  8131.49  8.4318  0.03  392.0  2388  100
# 2  14.62  ...  522.42  2388.03  8133.23  8.4178  0.03  390.0  2388  100
#
#      s20      s21
# 0  39.06  23.4190
# 1  39.00  23.4236
# 2  38.95  23.3442
#
# [3 rows x 26 columns]

# %%
df.columns
# Out:
# Index(['id', 'cycle', 'setting1', 'setting2', 'setting3', 's1', 's2', 's3',
#        's4', 's5', 's6', 's7', 's8', 's9', 's10', 's11', 's12', 's13', 's14',
#        's15', 's16', 's17', 's18', 's19', 's20', 's21'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32570 entries, 0 to 32569
# Data columns (total 26 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        32570 non-null  int64
#  1   cycle     32570 non-null  int64
#  2   setting1  32570 non-null  float64
#  3   setting2  32570 non-null  float64
#  4   setting3  32570 non-null  int64
#  5   s1        32570 non-null  float64
#  6   s2        32570 non-null  float64
#  7   s3        32570 non-null  float64
#  8   s4        32570 non-null  float64
#  9   s5        32570 non-null  float64
#  10  s6        32570 non-null  float64
#  11  s7        32570 non-null  float64
#  12  s8        32570 non-null  float64
#  13  s9        32570 non-null  float64
#  14  s10       32570 non-null  float64
#  15  s11       32570 non-null  float64
#  16  s12       32570 non-null  float64
#  17  s13       32570 non-null  float64
#  18  s14       32570 non-null  float64
# ...

# %%
df.describe()
# Out:
#                  id         cycle      setting1      setting2  setting3  \
# count  32570.000000  32570.000000  32570.000000  32570.000000   32570.0
# mean      49.935002     96.928861     -0.000008      0.000002     100.0
# std       28.094406     65.338717      0.002192      0.000293       0.0
# min        1.000000      1.000000     -0.008700     -0.000600     100.0
# 25%       26.000000     43.000000     -0.001500     -0.000200     100.0
# 50%       51.000000     89.000000      0.000000      0.000000     100.0
# 75%       74.000000    141.000000      0.001500      0.000300     100.0
# max      100.000000    362.000000      0.008700      0.000700     100.0
#
#              s1            s2            s3            s4            s5  ...  \
# count  32570.00  32570.000000  32570.000000  32570.000000  32570.000000  ...
# mean     518.67    642.605112   1589.630692   1407.383809     14.619582  ...
# std        0.00      0.476277      5.860803      8.469688      0.075469  ...
# ...

# %%
df['RUL'] = df.groupby('id')['cycle'].transform(max) - df['cycle']
feature_columns = ['setting1', 'setting2', 'setting3', 's1', 's2', 's3', 's4', 's5', 's6', 's7', 's8', 's9', 's10', 's11', 's12', 's13', 's14', 's15', 's16', 's17', 's18', 's19', 's20', 's21']

# %%
df=pd.merge(df,df_truth,on='id',how='left')

# %%
threshold=30
df['label']=(df['RUL']<=threshold).astype(int)

# %%
X_train,X_test,y_train,y_test=train_test_split(df[feature_columns],df['RUL'],
                                               test_size=0.2,random_state=42)

# %%
model=LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(X_test)
y_test_binary=(y_test<=threshold).astype(int)
y_pred_binary=(y_pred <=threshold).astype(int)

# %%
accuracy=accuracy_score(y_test_binary,y_pred_binary)
print(f'Accuracy:{accuracy}')
print(classification_report(y_test_binary,y_pred_binary))
# Out:
# Accuracy:0.9455019957015659
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97      5883
#            1       0.91      0.48      0.63       631
#
#     accuracy                           0.95      6514
#    macro avg       0.93      0.74      0.80      6514
# weighted avg       0.94      0.95      0.94      6514
